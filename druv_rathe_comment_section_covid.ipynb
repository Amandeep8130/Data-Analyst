# %% [markdown]
# <a href="https://colab.research.google.com/github/Amandeep8130/Data-Analyst/blob/main/druv_rathe_comment_section_covid.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
dev = 'AIzaSyAG33nx7LHbD6n8Utzbs6Kj3xaHdFbeBnE'

import googleapiclient.discovery
import pandas as pd

api_service_name = 'youtube'
api_version = 'v3'
DEVELOPER_KEY = 'AIzaSyAG33nx7LHbD6n8Utzbs6Kj3xaHdFbeBnE'

youtube = googleapiclient.discovery.build(
    api_service_name, api_version, developerKey=DEVELOPER_KEY)

request = youtube.commentThreads().list(
    part="snippet",
    videoId="aUZt-bY_0fo",
    maxResults=20000)

# %%
response = request.execute()

for item in response['items']:
  print(item)

response = request.execute()

for item in response['items']:
    print(item['snippet']['topLevelComment']['snippet']['textDisplay'])
# Out:
# {'kind': 'youtube#commentThread', 'etag': 'wszhqTb6710FEJyB3DVd5vGOWRk', 'id': 'UgxOOrZcwIlcPOZf8uF4AaABAg', 'snippet': {'channelId': 'UC-CSyyi47VX1lD9zyeABW3w', 'videoId': 'aUZt-bY_0fo', 'topLevelComment': {'kind': 'youtube#comment', 'etag': 'V1Dorw7pbvmE9vWnbr5tUJIbfmE', 'id': 'UgxOOrZcwIlcPOZf8uF4AaABAg', 'snippet': {'channelId': 'UC-CSyyi47VX1lD9zyeABW3w', 'videoId': 'aUZt-bY_0fo', 'textDisplay': 'Aaj bhi ki video kaun kaun  dekh rha h', 'textOriginal': 'Aaj bhi ki video kaun kaun  dekh rha h', 'authorDisplayName': '@ashwinipatel2748', 'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_lIzl-Xe8a5PM0pxZcqBj8I5v-SZ_yki407xd9e4liedhk=s48-c-k-c0x00ffffff-no-rj', 'authorChannelUrl': 'http://www.youtube.com/@ashwinipatel2748', 'authorChannelId': {'value': 'UClVc3QY_iHED1T-6RC3OXfA'}, 'canRate': True, 'viewerRating': 'none', 'likeCount': 0, 'publishedAt': '2024-05-08T15:30:09Z', 'updatedAt': '2024-05-08T15:30:09Z'}}, 'canReply': True, 'totalReplyCount': 0, 'isPublic': True}}
# ...
