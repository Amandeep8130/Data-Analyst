# %% [markdown]
# <a href="https://colab.research.google.com/github/Amandeep8130/Data-Analyst/blob/main/Untitled.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
carry minati most videws comment section scrapping
# Out:
#   File "<ipython-input-1-7d0d53cdd36f>", line 1
#     carry minati most videws comment section scrapping
#           ^
# SyntaxError: invalid syntax

# %%
import pandas as pd
import requests

# %%
api_service_name = 'youtube'
api_version = 'v3'
DEVELOPER_KEY = "AIzaSyD8gTvHyp1W_lC9rP8Nmq-HwazQgDiAFzM"

# %%
youtube = googleclient.discovery.build(api_service_name,api_version,developerkey = 'DEVELOPER_KEY ')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-73c8e21780af> in <cell line: 1>()
# ----> 1 youtube = googleclient.discovery.build(api_service_name,api_version,developerkey = 'DEVELOPER_KEY ')
#
# NameError: name 'googleclient' is not defined

# %%
import googleapiclient.discovery

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-873eaa21f28c> in <cell line: 1>()
# ----> 1 youtube = googleapiclient.discovery.build(
#       2     api_service_name, api_version, developerkey = DEVELOPER_KEY)
#       3
#
# /usr/local/lib/python3.10/dist-packages/googleapiclient/_helpers.py in positional_wrapper(*args, **kwargs)
#     128                 elif positional_parameters_enforcement == POSITIONAL_WARNING:
#     129                     logger.warning(message)
# --> 130             return wrapped(*args, **kwargs)
#     131
#     132         return positional_wrapper
#
# TypeError: build() got an unexpected keyword argument 'developerkey'

# %%
youtube = googleapiclient.discovery.build(
    api_service_name, api_version, developerKey=DEVELOPER_KEY)

# %%
request = youtube.commentThreads().list(  part="snippet",
    videoId="zzwRbKI2pn4",
    maxResults=400)

# %%
response = request.execute()

# %%
comments = []

for item in response['items']:
    comment = item['snippet']['topLevelComment']['snippet']
    comments.append([
        comment['authorDisplayName'],
        comment['publishedAt'],
        comment['updatedAt'],
        comment['likeCount'],
        comment['textDisplay']
    ])

df = pd.DataFrame(comments, columns=['author', 'published_at', 'updated_at', 'like_count', 'text'])

df.head(10)
# Out:
#                   author          published_at            updated_at  \
# 0           @CarryMinati  2020-06-05T17:38:26Z  2020-06-05T17:38:26Z
# 1       @Hero_is_back882  2023-12-01T18:54:16Z  2023-12-01T18:54:16Z
# 2            @Hunterkaka  2023-12-01T18:50:05Z  2023-12-01T18:50:05Z
# 3   @turtleblobgamer4630  2023-12-01T17:58:57Z  2023-12-01T17:58:57Z
# 4             @rizzu__67  2023-12-01T17:56:37Z  2023-12-01T17:56:37Z
# ..                   ...                   ...                   ...
# 90       @shahbazali8310  2023-11-29T14:54:09Z  2023-11-29T14:54:09Z
# 91       @RishiRaj-et7ux  2023-11-29T14:23:13Z  2023-11-29T14:23:13Z
# 92      @user-jl8th7fj5v  2023-11-29T13:58:24Z  2023-11-29T13:58:24Z
# 93      @Sanskar_Chafe11  2023-11-29T13:47:28Z  2023-11-29T13:47:28Z
# 94       @tusrajbhai4879  2023-11-29T13:46:50Z  2023-11-29T13:46:50Z
#
#     like_count                                               text
# 0      1973857  Isse ab yahi khatam karte hai mera hogye. <br>...
# ...

# %%
df.head(440)
# Out:
#                   author          published_at            updated_at  \
# 0           @CarryMinati  2020-06-05T17:38:26Z  2020-06-05T17:38:26Z
# 1       @Hero_is_back882  2023-12-01T18:54:16Z  2023-12-01T18:54:16Z
# 2            @Hunterkaka  2023-12-01T18:50:05Z  2023-12-01T18:50:05Z
# 3   @turtleblobgamer4630  2023-12-01T17:58:57Z  2023-12-01T17:58:57Z
# 4             @rizzu__67  2023-12-01T17:56:37Z  2023-12-01T17:56:37Z
# ..                   ...                   ...                   ...
# 90       @shahbazali8310  2023-11-29T14:54:09Z  2023-11-29T14:54:09Z
# 91       @RishiRaj-et7ux  2023-11-29T14:23:13Z  2023-11-29T14:23:13Z
# 92      @user-jl8th7fj5v  2023-11-29T13:58:24Z  2023-11-29T13:58:24Z
# 93      @Sanskar_Chafe11  2023-11-29T13:47:28Z  2023-11-29T13:47:28Z
# 94       @tusrajbhai4879  2023-11-29T13:46:50Z  2023-11-29T13:46:50Z
#
#     like_count                                               text
# 0      1973857  Isse ab yahi khatam karte hai mera hogye. <br>...
# ...

# %%
df['text']
# Out:
# 0     Isse ab yahi khatam karte hai mera hogye. <br>...
# 1                               CarryMinati Is The Best
# 2                                                  356M
# 3     Carry bhai maa ksm 200 bar sun liya gana mja a...
# 4                                           350M view❤❤
#                             ...
# 90          Is time per bhi kaun kaun song sun raha hai
# 91    Carryminati bhai aap se acha koi video nhi ban...
# 92                                                   Op
# 93                                      350 M crossed ❤
# 94                                                    ❤
# Name: text, Length: 95, dtype: object

# %%
import pandas as pd


series = pd.Series(df['text'])

print(series)
# Out:
# 0     Isse ab yahi khatam karte hai mera hogye. <br>...
# 1                               CarryMinati Is The Best
# 2                                                  356M
# 3     Carry bhai maa ksm 200 bar sun liya gana mja a...
# 4                                           350M view❤❤
#                             ...
# 90          Is time per bhi kaun kaun song sun raha hai
# 91    Carryminati bhai aap se acha koi video nhi ban...
# 92                                                   Op
# 93                                      350 M crossed ❤
# 94                                                    ❤
# Name: text, Length: 95, dtype: object
